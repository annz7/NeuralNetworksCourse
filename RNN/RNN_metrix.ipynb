# %%
import numpy as np
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot as plt
import pandas as pd

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = '/content/drive/My Drive/3 курс/NN/data/Results.txt'

# %%
predicted = []
expected = []

with open(data_path) as fp:
    line = fp.readline()
    while line:
      lst = line.split()
      expected.append(float(lst[0]))
      predicted.append(float(lst[1])) 
      line = fp.readline()

# %%
plt.plot(range(len(expected)), expected, label='expected')
plt.plot(range(len(predicted)), predicted, label='predicted')
plt.legend()

# %% [markdown]
# Кажется, что оно очень старается, но получается с точностью да наоборот.

# %%
plt.plot(pd.DataFrame(predicted) * -1, label='predicted')
plt.plot(pd.DataFrame(expected), label='expected')
plt.legend()

# %% [markdown]
# Действительно магия
